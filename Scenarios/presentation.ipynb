# %%
import os, sys

home = os.path.dirname(os.getcwd())
sys.path.insert(0, home + '\\Preprocess')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import random
import classifier as cl
import keras
from PIL import Image
import numpy as np
# Out:
# Using TensorFlow backend.
# c:\programdata\anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING: Logging before flag parsing goes to stderr.
# W1011 21:03:14.268630  7616 deprecation_wrapper.py:119] From D:\Rizza.Aulia\Telkom\Tugas Akhir\Scenarios\classifier.py:20: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# W1011 21:03:14.269631  7616 deprecation_wrapper.py:119] From D:\Rizza.Aulia\Telkom\Tugas Akhir\Scenarios\classifier.py:20: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.

# %%
model = keras.models.load_model(os.path.join(home, "Attributes\\CNN_scenario7.h5"))

# %%
imgs_dir = os.path.join(home, "Presentation Images")

test_imgs = []

for root, dirs, files in os.walk(imgs_dir):
    for f in files:
        img = Image.open(os.path.join(imgs_dir, f))
        img = img.resize((96, 96))
        img = np.array(img)
        img = img[:, :, :3]
        test_imgs.append(img)
        
random.shuffle(test_imgs)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for i in range(len(test_imgs)):
    plt.subplot(2, 3, i + 1)
    plt.axis('off')
    plt.imshow(test_imgs[i], cmap='gray')
    
plt.show()

# %%
for img in test_imgs:
    cl.test_img(img, model)
# Out:
# Caucasoid: 98.33%
# Negroid: 1.67%
# Mongoloid: 0.00%
# Caucasoid: 42.84%
# Negroid: 0.00%
# Mongoloid: 57.16%
# Caucasoid: 6.06%
# Negroid: 0.01%
# Mongoloid: 93.93%
# Caucasoid: 0.00%
# Negroid: 100.00%
# Mongoloid: 0.00%
# Caucasoid: 99.29%
# Negroid: 0.00%
# Mongoloid: 0.71%
# Caucasoid: 0.00%
# Negroid: 100.00%
# Mongoloid: 0.00%
